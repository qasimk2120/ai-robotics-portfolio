# %%
import getpass
import os
import pandas as pd
import pinecone
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer

# %%
files = pd.read_csv("../../../data/course_descriptions.csv", encoding='ANSI')

# %%
def create_course_Description(row):
    return f"The course name {row['course_name']}, the slug is : {row['course_slug']}, and the technology is : {row['course_technology']} and the course topic is : {row['course_topic']}"

# %%
pd.set_option('display.max_rows', 106)
files['course_description_new'] = files.apply(create_course_Description, axis=1)
print(files['course_description_new'])
# Out:
# 0      The course name Introduction to Tableau, the s...
# 1      The course name The Complete Data Visualizatio...
# 2      The course name Introduction to R Programming,...
# 3      The course name Data Preprocessing with NumPy,...
# 4      The course name Introduction to Data and Data ...
# 5      The course name Data Cleaning and Preprocessin...
# 6      The course name Introduction to Business Analy...
# 7      The course name Data Analysis with Excel Pivot...
# 8      The course name SQL, the slug is : sql, and th...
# 9      The course name Credit Risk Modeling in Python...
# 10     The course name Python Programmer Bootcamp, th...
# 11     The course name SQL + Tableau + Python, the sl...
# 12     The course name Introduction to Jupyter, the s...
# 13     The course name Statistics, the slug is : stat...
# 14     The course name Mathematics, the slug is : mat...
# 15     The course name Introduction to Excel, the slu...
# 16     The course name Probability, the slug is : pro...
# 17     The course name Starting a Career in Data Scie...
# 18     The course name SQL + Tableau, the slug is : s...
# 19     The course name Time Series Analysis with Pyth...
# 20     The course name Power BI, the slug is : introd...
# 21     The course name Product Management for AI & Da...
# 22     The course name Git and GitHub, the slug is : ...
# 23     The course name Deep Learning with TensorFlow,...
# 24     The course name Deep Learning with TensorFlow ...
# 25     The course name Customer Analytics in Python, ...
# 26     The course name Web Scraping and API Fundament...
# 27     The course name Introduction to Python, the sl...
# 28     The course name Python for Finance, the slug i...
# 29     The course name Machine Learning in Python, th...
# 30     The course name Advanced Microsoft Excel, the ...
# 31     The course name Convolutional Neural Networks ...
# 32     The course name Data Strategy, the slug is : d...
# 33     The course name Fashion Analytics with Tableau...
# 34     The course name Dates and Times in Python, the...
# 35     The course name SQL for Data Science Interview...
# 36     The course name Data Literacy, the slug is : d...
# 37     The course name AI Applications for Business S...
# 38     The course name Linear Algebra and Feature Sel...
# 39     The course name Machine Learning with Naive Ba...
# 40     The course name Machine Learning in Excel, the...
# 41     The course name Machine Learning with Support ...
# 42     The course name A/B Testing in Python, the slu...
# 43     The course name Machine Learning with Decision...
# 44     The course name Machine Learning with K-Neares...
# 45     The course name Machine Learning with Ridge an...
# 46     The course name Data-Driven Business Growth, t...
# 47     The course name Corporate Strategy, the slug i...
# 48     The course name Marketing Strategy, the slug i...
# 49     The course name Negotiation, the slug is : neg...
# 50     The course name Management, the slug is : mana...
# 51     The course name Persuasion and Influence, the ...
# 52     The course name Excel for Project Management, ...
# 53     The course name Agile and Scrum Project Manage...
# 54     The course name Project Management, the slug i...
# 55     The course name Blockchain for Business, the s...
# 56     The course name How to Think Like a Data Scien...
# 57     The course name Power Query and Data Modeling,...
# 58     The course name Introduction to DAX, the slug ...
# 59     The course name Building Business Reports Usin...
# 60     The course name The Machine Learning Process A...
# 61     The course name The Machine Learning Process A...
# 62     The course name Working with Text Files in Pyt...
# 63     The course name Intermediate Python Programmin...
# 64     The course name Advanced SQL, the slug is : ad...
# 65     The course name FP&A: Building a Company's Bud...
# 66     The course name Fixed Income Investments, the ...
# 67     The course name Accounting and Financial State...
# 68     The course name Fundamentals of Financial Repo...
# 69     The course name Building a 3-Statement Model i...
# 70     The course name Financial Ratio Analysis , the...
# 71     The course name Corporate Finance , the slug i...
# 72     The course name Fundamentals of Financial Mark...
# 73     The course name Introduction to Industry and C...
# 74     The course name Fundamentals of Equity Valuati...
# 75     The course name Introduction to Equity Securit...
# 76     The course name Alternative Investments, the s...
# 77     The course name Advanced Financial Reporting -...
# 78     The course name Advanced Financial Reporting -...
# 79     The course name Macroeconomics, the slug is : ...
# 80     The course name Who Does What in Finance, the ...
# 81     The course name Investment Banking, the slug i...
# 82     The course name Discounted Cash Flow Valuation...
# 83     The course name Multiples Valuation, the slug ...
# 84     The course name LBO Modeling in Excel, the slu...
# 85     The course name Math for Finance, the slug is ...
# 86     The course name Derivatives, the slug is : der...
# 87     The course name Portfolio Management, the slug...
# 88     The course name Technical Analysis, the slug i...
# 89     The course name The Machine Learning Algorithm...
# 90     The course name Customer Churn Analysis with S...
# 91     The course name Machine Learning Deep Dive: Bu...
# 92     The course name Customer Engagement Analysis w...
# 93     The course name Advanced SQL for Data Engineer...
# 94     The course name Communication and Presentation...
# 95     The course name Intro to PowerPoint, the slug ...
# 96     The course name Intro to ChatGPT and Generativ...
# 97     The course name Data Analysis in Power BI with...
# 98     The course name Mastering Key Performance Indi...
# 99     The course name Sign-Up Flow Optimization Anal...
# 100    The course name Python for Social Media Analyt...
# 101    The course name Intro to NLP for AI, the slug ...
# 102    The course name Data Analysis with ChatGPT, th...
# 103    The course name ChatGPT for Data Science, the ...
# 104    The course name Intro to LLMs, the slug is : i...
# 105    The course name Growth Analysis with SQL, Pyth...
# Name: course_description_new, dtype: object

# %%
pc = Pinecone(api_key= os.environ.get("PINECONE_API_KEY"), environment= os.environ.get("PINECONE_ENV"))

# %%
index_name = "my-index"
dimension = 384  # Dimension of the embeddings
metric = "cosine"  # Similarity metric

# %%
if index_name in [i.name for i in pc.list_indexes()]:
    pc.delete_index(index_name)
    print(f"Deleted existing index '{index_name}'.")
else:
    print(f"{index_name} not in the index list.")
# Out:
# Deleted existing index 'my-index'.

# %%
pc.create_index(
    name=index_name,
    dimension=dimension,
    metric=metric,
    spec = ServerlessSpec( cloud="aws", region="us-east-1")
)
# Out:
# {
#     "name": "my-index",
#     "metric": "cosine",
#     "host": "my-index-jo7crz3.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 384,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "access-control-allow-origin": "*",
#             "vary": "origin,access-control-request-method,access-control-request-headers",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "b7f0fbf6ea190248c85b6d42d07ad248",
#             "date": "Sat, 10 Jan 2026 18:41:22 GMT",
#             "server": "Google Frontend",
#             "content-length": "385",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
index =  pc.Index(index_name)

# %%
#Embedding the data

# %%
model =  SentenceTransformer('all-MiniLM-L6-v2')

# %%
def create_embedding(row):
    combined_text = ' '.join([str(row[field]) for field in ['course_description', 'course_description_new', 'course_description_short']])
    embedding =  model.encode(combined_text, show_progress_bar=False)
    return embedding

# %%
files["embedding"] = files.apply(create_embedding, axis=1)

# %%
vectors_to_upsert = [(str(row['course_name']), row['embedding'].tolist()) for _, row in files.iterrows()]
index.upsert(vectors=vectors_to_upsert)

print("Data upserted successfully.")
# Out:
# Data upserted successfully.

# %% [markdown]
# Semantic Search

# %%
query = "Clustering"
query_embedding = model.encode(query).tolist()

# %%
query_results = index.query( vector= [query_embedding], top_k=12, include_metadata=True)

# %%
query_results
# Out:
# QueryResponse(matches=[{'id': 'Machine Learning in Excel',
#  'metadata': {},
#  'score': 0.349885464,
#  'values': []}, {'id': 'Growth Analysis with SQL, Python, and Tableau  ',
#  'metadata': {},
#  'score': 0.249427766,
#  'values': []}, {'id': 'Machine Learning with Support Vector Machines',
#  'metadata': {},
#  'score': 0.225214019,
#  'values': []}, {'id': 'Introduction to Industry and Company Analysis',
#  'metadata': {},
#  'score': 0.201858535,
#  'values': []}, {'id': 'Machine Learning in Python',
#  'metadata': {},
#  'score': 0.275269508,
#  'values': []}, {'id': 'Fashion Analytics with Tableau',
#  'metadata': {},
#  'score': 0.235293403,
#  'values': []}, {'id': 'Customer Churn Analysis with SQL and Tableau',
#  'metadata': {},
#  'score': 0.2750597,
#  'values': []}, {'id': 'Machine Learning with Naive Bayes',
#  'metadata': {},
#  'score': 0.211933136,
#  'values': []}, {'id': 'Machine Learning with K-Nearest Neighbors',
#  'metadata': {},
#  'score': 0.288754463,
#  'values': []}, {'id': 'Linear Algebra and Feature Selection',
#  'metadata': {},
#  'score': 0.250612259,
#  'values': []}, {'id': 'Customer Engagement Analysis with SQL and Tableau',
#  'metadata': {},
#  'score': 0.220272064,
#  'values': []}, {'id': 'Data Analysis with Excel Pivot Tables',
#  'metadata': {},
#  'score': 0.199047565,
#  'values': []}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Sat, 10 Jan 2026 18:41:32 GMT', 'content-type': 'application/json', 'content-length': '1193', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '1', 'x-pinecone-request-latency-ms': '34', 'x-pinecone-request-id': '5559415879777959442', 'x-envoy-upstream-service-time': '35', 'x-pinecone-response-duration-ms': '36', 'grpc-status': '0', 'server': 'envoy'}})

# %%
score_threshold = 0.3
for match in query_results['matches']:
    if match['score'] >= score_threshold:
        print(f"Course Name: {match['id']}, Score: {match['score']}")
# Out:
# Course Name: Machine Learning in Excel, Score: 0.349885464
